# %% [markdown]
# <a href="https://colab.research.google.com/github/HomemJaguar111/Brinquedos/blob/main/Mapas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import folium

# %%
mapa = folium.Map()

# %% [markdown]
# folium.Marker(
#     [,],
#     popup='<i>Ciudad Blanca</i>'
# ).add_to(mapa)

# %%
folium.Marker(
    [41.409767,-122.201180],
    popup='<i>Monte Shasta</i>'
).add_to(mapa)

folium.Marker(
    [20.39243,-101.19123],
    popup='<i>Vale Siete Luminarias</i>'
).add_to(mapa)

folium.Marker(
    [15.49730,-84.95823],
    popup='<i>Ciudad Blanca</i>'
).add_to(mapa)

folium.Marker( 
    [4.93457,-73.83412], 
    popup='Guatavita' 
    ).add_to(mapa)

folium.Marker( 
    [5.14127,-60.73919], 
    popup='Roraima' 
    ).add_to(mapa)
    
folium.Marker( 
    [-3.05051,-78.20519], 
    popup='Cueva de los Tayos' 
    ).add_to(mapa)

folium.Marker( 
    [-12.48123,-69.17607], 
    popup='Paititi' 
    ).add_to(mapa)
    
folium.Marker( 
    [-15.80197,-69.33005], 
    popup='Lago Titicaca' 
    ).add_to(mapa)

folium.Marker( 
    [-22.11740,-67.95938], 
    popup='Licancabur' 
    ).add_to(mapa)

folium.Marker( 
    [-29.88980,-67.85360], 
    popup='Talampaya' 
    ).add_to(mapa)    

folium.Marker( 
    [-14.34881,-52.16022], 
    popup='Serra do Roncador' 
    ).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
